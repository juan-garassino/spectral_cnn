# %% [markdown]
# # Spectral CNN Benchmark Demo
#
# This notebook runs the Spectral CNN benchmark using the code from the repository.

# %%
# !git clone https://github.com/juan-garassino/spectral_cnn.git
# %cd spectral_cnn

# %%
# !pip install -r requirements.txt

# %%
# !python main.py

# %%
import glob
from IPython.display import Image, display

# Find the latest result folder
folders = sorted(glob.glob("./WeightParam_Benchmark_*"))
if folders:
    latest_folder = folders[-1]
    print(f"Viewing results from: {latest_folder}")

    # Display images
    images = glob.glob(f"{latest_folder}/*.png")
    for img_path in images:
        print(f"--- {img_path} ---")
        display(Image(img_path))
else:
    print("No results found. Did the training run successfully?")
